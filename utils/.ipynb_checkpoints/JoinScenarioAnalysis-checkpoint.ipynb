# %%
# Import all libraries needed for the tutorial

# General syntax to import specific functions in a library: 
##from (library) import (specific library function)
from pandas import DataFrame, read_csv

# General syntax to import a library but no functions: 
##import (library) as (give the library a nickname/alias)
import matplotlib.pyplot as plt
import pandas as pd #this is how I usually import pandas
import sys #only needed to determine Python version number
import matplotlib #only needed to determine Matplotlib version number
import numpy

from pylab import *

# Enable inline plotting
# %matplotlib inline

# %%
cdf = pd.read_csv(r'commDelays2.csv')

# %%
cdf.head(5)
# Out:
#                                              run     type module name  \
# 0  JoinScenarioSimpleAI-9-20181001-09:33:05-2615  runattr    NaN  NaN
# 1  JoinScenarioSimpleAI-9-20181001-09:33:05-2615  runattr    NaN  NaN
# 2  JoinScenarioSimpleAI-9-20181001-09:33:05-2615  runattr    NaN  NaN
# 3  JoinScenarioSimpleAI-9-20181001-09:33:05-2615  runattr    NaN  NaN
# 4  JoinScenarioSimpleAI-9-20181001-09:33:05-2615  runattr    NaN  NaN
#
#         attrname                                          attrvalue  value
# 0     configname                               JoinScenarioSimpleAI    NaN
# 1       datetime                                  20181001-09:33:05    NaN
# 2     experiment                               JoinScenarioSimpleAI    NaN
# 3        inifile                                        omnetpp.ini    NaN
# 4  iterationvars  $rule="Plurality", $situation="Unstable", $nCa...    NaN

# %%
timeToConsensus = cdf[cdf["name"] == '#timeToConsensus']
timeToConsensus.head()
# Out:
#                                                     run    type  \
# 114412  JoinScenarioSimpleAI-43-20180929-18:28:46-16346  scalar
# 114423    JoinScenarioSimpleAI-48-20181001-09:07:10-388  scalar
# 114430   JoinScenarioSimpleAI-52-20180929-17:14:58-8372  scalar
# 114437  JoinScenarioSimpleAI-68-20180929-18:18:28-14962  scalar
# 114452  JoinScenarioSimpleAI-60-20180929-17:54:06-12500  scalar
#
#                          module              name attrname attrvalue  \
# 114412  JoinNetworkAI.ljmanager  #timeToConsensus      NaN       NaN
# 114423  JoinNetworkAI.ljmanager  #timeToConsensus      NaN       NaN
# 114430  JoinNetworkAI.ljmanager  #timeToConsensus      NaN       NaN
# 114437  JoinNetworkAI.ljmanager  #timeToConsensus      NaN       NaN
# 114452  JoinNetworkAI.ljmanager  #timeToConsensus      NaN       NaN
#
#              value
# 114412  125.820894
# 114423  100.243645
# 114430  154.105767
# 114437  132.223406
# 114452  702.313376

# %%
timeToConsensus.value.describe()
# Out:
# count     800.000000
# mean      205.383870
# std       247.289354
# min        -1.000000
# 25%        99.448995
# 50%       133.402941
# 75%       170.121529
# max      1649.276982
# Name: value, dtype: float64

# %%
test = cdf[(cdf.name=='#timeToConsensus') | (cdf.attrname=='platoonSize') ]
test = test.assign(qname = test.attrname.combine_first(test.module + '.' + test.name))
test.value = test.value.combine_first(test.attrvalue.astype('float64'))
test[['run','name','attrname','value','attrvalue', 'qname']]
# Out:
#                                                    run              name  \
# 17       JoinScenarioSimpleAI-9-20181001-09:33:05-2615               NaN
# 122     JoinScenarioSimpleAI-15-20181001-09:33:31-2663               NaN
# 122988   JoinScenarioSimpleAI-0-20181001-09:32:24-2358  #timeToConsensus
# 122999   JoinScenarioSimpleAI-1-20181001-09:32:29-2367  #timeToConsensus
# 123010   JoinScenarioSimpleAI-2-20181001-09:32:34-2551  #timeToConsensus
# 123021   JoinScenarioSimpleAI-3-20181001-09:32:38-2560  #timeToConsensus
# 123032   JoinScenarioSimpleAI-4-20181001-09:32:43-2574  #timeToConsensus
# 123043   JoinScenarioSimpleAI-5-20181001-09:32:47-2582  #timeToConsensus
# 123054   JoinScenarioSimpleAI-6-20181001-09:32:52-2590  #timeToConsensus
# 123065   JoinScenarioSimpleAI-7-20181001-09:32:56-2598  #timeToConsensus
# 123076   JoinScenarioSimpleAI-8-20181001-09:33:00-2606  #timeToConsensus
# 123087  JoinScenarioSimpleAI-10-20181001-09:33:09-2623  #timeToConsensus
# 123098   JoinScenarioSimpleAI-9-20181001-09:33:05-2615  #timeToConsensus
# 123109  JoinScenarioSimpleAI-11-20181001-09:33:13-2631  #timeToConsensus
# 123120  JoinScenarioSimpleAI-12-20181001-09:33:18-2639  #timeToConsensus
# 123131  JoinScenarioSimpleAI-13-20181001-09:33:22-2647  #timeToConsensus
# 123142  JoinScenarioSimpleAI-14-20181001-09:33:26-2655  #timeToConsensus
# 123153  JoinScenarioSimpleAI-15-20181001-09:33:31-2663  #timeToConsensus
# 123164  JoinScenarioSimpleAI-16-20181001-09:33:35-2673  #timeToConsensus
# 123175  JoinScenarioSimpleAI-17-20181001-09:33:40-2681  #timeToConsensus
# 123186  JoinScenarioSimpleAI-18-20181001-09:33:44-2689  #timeToConsensus
# 123197  JoinScenarioSimpleAI-19-20181001-09:33:49-2697  #timeToConsensus
#
#            attrname       value attrvalue  \
# 17      platoonSize    4.000000         4
# 122     platoonSize    4.000000         4
# 227     platoonSize    4.000000         4
# 332     platoonSize    4.000000         4
# 437     platoonSize    4.000000         4
# 542     platoonSize    4.000000         4
# 647     platoonSize    4.000000         4
# 752     platoonSize    4.000000         4
# 857     platoonSize    4.000000         4
# 962     platoonSize    4.000000         4
# 1067    platoonSize    4.000000         4
# 1172    platoonSize    4.000000         4
# 1277    platoonSize    4.000000         4
# 1382    platoonSize    4.000000         4
# 1487    platoonSize    4.000000         4
# 1592    platoonSize    4.000000         4
# 1697    platoonSize    4.000000         4
# 1802    platoonSize    4.000000         4
# 1907    platoonSize    4.000000         4
# 2012    platoonSize    4.000000         4
# 2117    platoonSize    4.000000         4
# 2222    platoonSize    4.000000         4
# 2327    platoonSize    4.000000         4
# 2432    platoonSize    4.000000         4
# 2537    platoonSize    4.000000         4
# 2642    platoonSize    4.000000         4
# 2747    platoonSize    4.000000         4
# 2852    platoonSize    4.000000         4
# 2957    platoonSize    4.000000         4
# 3062    platoonSize    4.000000         4
# ...             ...         ...       ...
# 122878          NaN   84.334901       NaN
# 122889          NaN   95.874818       NaN
# 122900          NaN   90.915460       NaN
# 122911          NaN  110.209012       NaN
# 122922          NaN   70.241607       NaN
# 122933          NaN  570.234462       NaN
# 122944          NaN   90.244965       NaN
# 122955          NaN   90.234614       NaN
# 122966          NaN   80.238748       NaN
# 122977          NaN   -1.000000       NaN
# 122988          NaN  260.233830       NaN
# 122999          NaN  200.234820       NaN
# 123010          NaN  150.243383       NaN
# 123021          NaN  138.297339       NaN
# 123032          NaN  120.243071       NaN
# 123043          NaN  160.237905       NaN
# 123054          NaN   90.236113       NaN
# 123065          NaN  130.245788       NaN
# 123076          NaN  100.236155       NaN
# 123087          NaN   80.244961       NaN
# 123098          NaN   70.496131       NaN
# 123109          NaN  156.696017       NaN
# 123120          NaN  120.237931       NaN
# 123131          NaN   90.235934       NaN
# 123142          NaN  103.134545       NaN
# 123153          NaN   70.234402       NaN
# 123164          NaN  120.242304       NaN
# 123175          NaN   61.536635       NaN
# 123186          NaN  120.238953       NaN
# 123197          NaN   92.456762       NaN
#
#                                            qname
# 17                                   platoonSize
# 122                                  platoonSize
# 227                                  platoonSize
# 332                                  platoonSize
# 437                                  platoonSize
# 542                                  platoonSize
# 647                                  platoonSize
# 752                                  platoonSize
# 857                                  platoonSize
# 962                                  platoonSize
# 1067                                 platoonSize
# 1172                                 platoonSize
# 1277                                 platoonSize
# 1382                                 platoonSize
# 1487                                 platoonSize
# 1592                                 platoonSize
# 1697                                 platoonSize
# 1802                                 platoonSize
# 1907                                 platoonSize
# 2012                                 platoonSize
# 2117                                 platoonSize
# 2222                                 platoonSize
# 2327                                 platoonSize
# 2432                                 platoonSize
# 2537                                 platoonSize
# 2642                                 platoonSize
# 2747                                 platoonSize
# 2852                                 platoonSize
# 2957                                 platoonSize
# 3062                                 platoonSize
# ...                                          ...
# 122878  JoinNetworkAI.ljmanager.#timeToConsensus
# 122889  JoinNetworkAI.ljmanager.#timeToConsensus
# 122900  JoinNetworkAI.ljmanager.#timeToConsensus
# 122911  JoinNetworkAI.ljmanager.#timeToConsensus
# 122922  JoinNetworkAI.ljmanager.#timeToConsensus
# 122933  JoinNetworkAI.ljmanager.#timeToConsensus
# 122944  JoinNetworkAI.ljmanager.#timeToConsensus
# 122955  JoinNetworkAI.ljmanager.#timeToConsensus
# 122966  JoinNetworkAI.ljmanager.#timeToConsensus
# 122977  JoinNetworkAI.ljmanager.#timeToConsensus
# 122988  JoinNetworkAI.ljmanager.#timeToConsensus
# 122999  JoinNetworkAI.ljmanager.#timeToConsensus
# 123010  JoinNetworkAI.ljmanager.#timeToConsensus
# 123021  JoinNetworkAI.ljmanager.#timeToConsensus
# 123032  JoinNetworkAI.ljmanager.#timeToConsensus
# 123043  JoinNetworkAI.ljmanager.#timeToConsensus
# 123054  JoinNetworkAI.ljmanager.#timeToConsensus
# 123065  JoinNetworkAI.ljmanager.#timeToConsensus
# 123076  JoinNetworkAI.ljmanager.#timeToConsensus
# 123087  JoinNetworkAI.ljmanager.#timeToConsensus
# 123098  JoinNetworkAI.ljmanager.#timeToConsensus
# 123109  JoinNetworkAI.ljmanager.#timeToConsensus
# JoinScenarioSimpleAI-10-20180929-17:36:13-10660          5.0
# JoinScenarioSimpleAI-10-20180929-17:48:43-11879          5.0
# JoinScenarioSimpleAI-10-20180929-18:00:46-13055          5.0
# JoinScenarioSimpleAI-10-20181001-09:18:08-1249           4.0
# JoinScenarioSimpleAI-10-20181001-09:31:37-2158           4.0
# JoinScenarioSimpleAI-10-20181001-09:33:09-2623           4.0
# JoinScenarioSimpleAI-11-20180929-17:36:18-10675          5.0
# JoinScenarioSimpleAI-11-20180929-17:48:48-11889          5.0

# %%
# set the default image resolution and size
#plt.rcParams['figure.figsize'] = [8.0, 5.0]
#plt.rcParams['figure.dpi'] = 144
fig = figure( figsize=(9,6.5) )
ax  = fig.add_subplot(111)
ax.set_ylabel('ms')

# create a scatter plot
#test_wide.plot.scatter('platoonSize', 'JoinNetworkAI.ljmanager.#timeToConsensus')
#plt.show()
#test_wide.plot.boxplot('platoonSize', 'JoinNetworkAI.ljmanager.#timeToConsensus')
box = test_wide.boxplot(ax=ax, column=['JoinNetworkAI.ljmanager.#timeToConsensus'], by='platoonSize', showfliers=False)
plt.suptitle('')
plt.title('Time to consensus by Platoon Size')
#plt.show()
plt.savefig('TimeToConsensus.png')

# %%
memberDelay = cdf[(cdf.name=='#highestDelayToMember') | (cdf.attrname=='platoonSize')]
memberDelay = memberDelay.assign(qname = memberDelay.attrname.combine_first(memberDelay.module + '.' + memberDelay.name))
memberDelay.value = memberDelay.value.combine_first(memberDelay.attrvalue.astype('float64'))

memberDelay = memberDelay.pivot('run', columns='qname', values='value')
memberDelay.head(20)
# Out:
# qname                                            JoinNetworkAI.ljmanager.#highestDelayToMember  \
# run
# JoinScenarioSimpleAI-0-20180929-17:35:20-10533                                       10.032196
# JoinScenarioSimpleAI-0-20180929-17:47:52-11771                                        6.051391
# JoinScenarioSimpleAI-0-20180929-17:59:55-12930                                        0.239417
# JoinScenarioSimpleAI-0-20181001-09:17:22-1060                                         0.240037
# JoinScenarioSimpleAI-0-20181001-09:30:52-2067                                         0.925163
# JoinScenarioSimpleAI-0-20181001-09:32:24-2358                                         0.245834
# JoinScenarioSimpleAI-1-20180929-17:35:26-10552                                        4.511483
# JoinScenarioSimpleAI-1-20180929-17:47:58-11780                                        6.696708
# JoinScenarioSimpleAI-1-20180929-18:00:01-12958                                        5.689675
# JoinScenarioSimpleAI-1-20181001-09:17:28-1089                                         0.244572
# JoinScenarioSimpleAI-1-20181001-09:30:57-2084                                         5.607233
# JoinScenarioSimpleAI-1-20181001-09:32:29-2367                                         4.306492
# JoinScenarioSimpleAI-10-20180929-17:36:13-10660                                       3.357390
# JoinScenarioSimpleAI-10-20180929-17:48:43-11879                                       3.915675
# JoinScenarioSimpleAI-10-20180929-18:00:46-13055                                       1.735964
# JoinScenarioSimpleAI-10-20181001-09:18:08-1249                                        3.255961
# JoinScenarioSimpleAI-10-20181001-09:31:37-2158                                        3.935416
# JoinScenarioSimpleAI-10-20181001-09:33:09-2623                                        1.599946
# JoinScenarioSimpleAI-11-20180929-17:36:18-10675                                      24.447824
# JoinScenarioSimpleAI-11-20180929-17:48:48-11889                                     504.386510
#
# qname                                            platoonSize
# run
# JoinScenarioSimpleAI-0-20180929-17:35:20-10533           5.0
# JoinScenarioSimpleAI-0-20180929-17:47:52-11771           5.0
# JoinScenarioSimpleAI-0-20180929-17:59:55-12930           5.0
# JoinScenarioSimpleAI-0-20181001-09:17:22-1060            4.0
# JoinScenarioSimpleAI-0-20181001-09:30:52-2067            4.0
# JoinScenarioSimpleAI-0-20181001-09:32:24-2358            4.0
# JoinScenarioSimpleAI-1-20180929-17:35:26-10552           5.0
# JoinScenarioSimpleAI-1-20180929-17:47:58-11780           5.0
# JoinScenarioSimpleAI-1-20180929-18:00:01-12958           5.0
# JoinScenarioSimpleAI-1-20181001-09:17:28-1089            4.0
# JoinScenarioSimpleAI-1-20181001-09:30:57-2084            4.0
# JoinScenarioSimpleAI-1-20181001-09:32:29-2367            4.0
# JoinScenarioSimpleAI-10-20180929-17:36:13-10660          5.0
# JoinScenarioSimpleAI-10-20180929-17:48:43-11879          5.0
# JoinScenarioSimpleAI-10-20180929-18:00:46-13055          5.0
# JoinScenarioSimpleAI-10-20181001-09:18:08-1249           4.0
# JoinScenarioSimpleAI-10-20181001-09:31:37-2158           4.0
# JoinScenarioSimpleAI-10-20181001-09:33:09-2623           4.0
# JoinScenarioSimpleAI-11-20180929-17:36:18-10675          5.0
# JoinScenarioSimpleAI-11-20180929-17:48:48-11889          5.0

# %%
fig = figure( figsize=(9,6.5) )
ax  = fig.add_subplot(111)
ax.set_ylabel('ms')

box = memberDelay.boxplot(ax=ax, column=['JoinNetworkAI.ljmanager.#highestDelayToMember'], by='platoonSize', showfliers=False)
plt.suptitle('')
plt.title('Max communication delay to platoon members')
#plt.show()
plt.savefig('HighestMemberDelay.png')

# %%
udf = pd.read_csv(r'averageUtils.csv')

udf_pivot = udf[udf.Scenario == "Stable"].pivot_table(index='Size', columns='Rule', values='Average')

udf_pivot.head(10)
# Out:
# Rule  Approval     Borda  Copeland  Plurality
# Size
# 4    -0.054875 -0.000262 -0.000535  -0.033152
# 5    -0.047225  0.002283 -0.003722  -0.014049
# 6    -0.046100  0.000420 -0.001624  -0.026063
# 7    -0.044171 -0.001165 -0.001674  -0.023657
# 8    -0.020056 -0.002515 -0.000027  -0.038437

# %%
udf_pivot = udf[udf.Scenario == "Stable"].pivot_table(index='Size', columns='Rule', values='Average')

fig = figure( figsize=(9,6.5) )
ax  = fig.add_subplot(111)
ax.set_xticks(numpy.arange(0, 10, 1))
udf_pivot.plot.line(ax=ax,linestyle='--', marker='o')
#udf.plot.scatter(ax=ax, y='Average', x='Size')
plt.grid()
plt.title("Average utility differences in a stable scenario")
plt.ylabel('Utility difference')
plt.xlabel('Platoon Size')
plt.show()
#plt.savefig('StableUtilityDiff.png')

# %%
udf_pivot_u = udf[udf.Scenario == "Unstable"].pivot_table(index='Size', columns='Rule', values='Average')

fig = figure( figsize=(9,6.5) )
ax  = fig.add_subplot(111)
ax.set_xticks(numpy.arange(0, 10, 1))
udf_pivot_u.plot.line(ax=ax,linestyle='--', marker='o')

plt.grid()
plt.title("Average utility differences in an unstable scenario")
plt.ylabel('Utility difference')
plt.xlabel('Platoon Size')
plt.savefig('UnstableUtilityDiff.png')

# %%
itervars_df = cdf.loc[cdf.type=='itervar', ['run', 'attrname', 'attrvalue']]

#itervars_df[cdf.attrname=='rule'].head()

itervarspivot_df = itervars_df[cdf.attrname=='rule'].pivot(index='run', columns='attrname', values='attrvalue')
#itervarspivot_df.head()

ruleTimeToConsensus = test_wide.merge(itervarspivot_df, left_on='run', right_index=True, how='outer')
#ruleTimeToConsensus[ruleTimeToConsensus.rule.str.contains('Borda')].head()


fig = figure( figsize=(9,6.5) )
ax  = fig.add_subplot(111)
ax.set_ylabel('ms')

box = ruleTimeToConsensus[ruleTimeToConsensus.rule.str.contains('Borda')].boxplot(ax=ax, column=['JoinNetworkAI.ljmanager.#timeToConsensus'], by='platoonSize', showfliers=False)
plt.suptitle('')
plt.title('Time to consensus by Platoon Size, Borda rule')
plt.savefig('TimeToConsensusBorda.png')
# Out:
# /usr/lib/python3.7/site-packages/ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """

# %%
fig = figure( figsize=(9,6.5) )
ax  = fig.add_subplot(111)
ax.set_ylabel('ms')

box = ruleTimeToConsensus[ruleTimeToConsensus.rule.str.contains('Copeland')].boxplot(ax=ax, column=['JoinNetworkAI.ljmanager.#timeToConsensus'], by='platoonSize', showfliers=False)
plt.suptitle('')
plt.title('Time to consensus by Platoon Size, Copeland rule')
plt.savefig('TimeToConsensusCopeland.png')

# %%
fig = figure( figsize=(9,6.5) )
ax  = fig.add_subplot(111)
ax.set_ylabel('ms')

box = ruleTimeToConsensus[ruleTimeToConsensus.rule.str.contains('Approval')].boxplot(ax=ax, column=['JoinNetworkAI.ljmanager.#timeToConsensus'], by='platoonSize', showfliers=False)
plt.suptitle('')
plt.title('Time to consensus by Platoon Size, Approval rule')
plt.savefig('TimeToConsensusApproval.png')

# %%
fig = figure( figsize=(9,6.5) )
ax  = fig.add_subplot(111)
ax.set_ylabel('ms')

box = ruleTimeToConsensus[ruleTimeToConsensus.rule.str.contains('Plurality')].boxplot(ax=ax, column=['JoinNetworkAI.ljmanager.#timeToConsensus'], by='platoonSize', showfliers=False)
plt.suptitle('')
plt.title('Time to consensus by Platoon Size, Plurality rule')
plt.savefig('TimeToConsensusPlurality.png')

# %%
adf = pd.read_csv(r'abandonRates.csv')

adf_pivot = adf[udf.Scenario == "Stable"].pivot_table(index='Size', columns='Rule', values='Exits')


adf_pivot.head(10)
# Out:
# Rule  Approval  Borda  Copeland  Plurality
# Size
# 4          0.0    0.0       0.0   5.000000
# 5          0.0    0.0       0.0   2.000000
# 6          0.0    0.0       0.0   1.666667
# 7          0.0    0.0       0.0   2.857143
# 8          0.0    0.0       0.0   6.250000

# %%
fig = figure( figsize=(9,6.5) )
ax  = fig.add_subplot(111)
ax.set_ylabel('Percentage of platoon exit')
adf_pivot.plot.bar(ax=ax)
plt.savefig('ExitPercentageStable.png')

# %%
adf_pivot_u = adf[udf.Scenario == "Unstable"].pivot_table(index='Size', columns='Rule', values='Exits')


adf_pivot_u.head(10)
# Out:
# Rule  Approval     Borda  Copeland  Plurality
# Size
# 4          0.0  1.250000  1.250000  11.250000
# 5          0.0  3.000000  3.000000   6.000000
# 6          0.0  5.000000  4.166667  10.000000
# 7          0.0  7.142857  2.857143  15.714286
# 8          0.0  5.000000  3.125000  13.125000

# %%
fig = figure( figsize=(9,6.5) )
ax  = fig.add_subplot(111)
ax.set_ylabel('Percentage of platoon exit')
adf_pivot_u.plot.bar(ax=ax)
plt.savefig('ExitPercentageUnstable.png')

# %%
audf = pd.read_csv(r'utilities.csv')

unstables = audf[(audf.Scenario=='Unstable')]  # filter rows
unstables = stables.assign(qname = str(stables.Agent) + '.' + str(stables.Iteration))  # add qname column
unstables[['Rule', 'Difference', 'PlatoonSize','qname']].iloc[80:90]  # print an excerpt of the result

stables = audf[(audf.Scenario=='Stable')]  # filter rows
stables = stables.assign(qname = str(stables.Agent) + '.' + str(stables.Iteration))  # add qname column
# Out:
#      Rule  Difference  PlatoonSize  \
# 80  Borda    0.053795            5
# 81  Borda   -0.495041            5
# 82  Borda   -0.105894            5
# 83  Borda    0.223674            5
# 84  Borda    0.053795            5
# 85  Borda   -0.001440            5
# 86  Borda    0.007276            5
# 87  Borda   -0.000367            5
# 88  Borda    0.069731            5
# 89  Borda    0.034452            5
#
#                                                 qname
# 80  0       0\n1       1\n2       2\n3       3\n4 ...
# 81  0       0\n1       1\n2       2\n3       3\n4 ...
# 82  0       0\n1       1\n2       2\n3       3\n4 ...
# 83  0       0\n1       1\n2       2\n3       3\n4 ...
# 84  0       0\n1       1\n2       2\n3       3\n4 ...
# 85  0       0\n1       1\n2       2\n3       3\n4 ...
# 86  0       0\n1       1\n2       2\n3       3\n4 ...
# 87  0       0\n1       1\n2       2\n3       3\n4 ...
# 88  0       0\n1       1\n2       2\n3       3\n4 ...
# 89  0       0\n1       1\n2       2\n3       3\n4 ...

# %%
fig = figure( figsize=(9,6.5) )
ax  = fig.add_subplot(111)
ax.set_ylabel('ms')
ax.set_xticks(numpy.arange(0, 10, 1))

#stables[stables.Rule=="Copeland"].boxplot(ax=ax, column=['Difference'], by='PlatoonSize', showfliers=False)
stables[stables.Rule=="Copeland"].plot.scatter(x='PlatoonSize', y='Difference',ax=ax )
plt.suptitle('')
plt.title('Utility differences Copeland')
plt.show()

# %%
fig = figure( figsize=(9,6.5) )
ax  = fig.add_subplot(111)
ax.set_ylabel('ms')
ax.set_xticks(numpy.arange(0, 10, 1))

#stables[stables.Rule=="Copeland"].boxplot(ax=ax, column=['Difference'], by='PlatoonSize', showfliers=False)
stables[stables.Rule=="Approval"].plot.scatter(x='PlatoonSize', y='Difference',ax=ax )
plt.suptitle('')
plt.title('Utility differences Approval')
plt.show()
